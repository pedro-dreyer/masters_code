# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append('..')
from misc.experiment_loader import *
# import matplotlib.pyplot as plt


folder_path = '../results/cifar10/resnet18_/best_results_vgg19/'
full_experiment = FullExperiment(folder_path=folder_path)
test_experiment = full_experiment.filter_parameters({'training_method':'sgd'})

# %%
full_experiment.plot_compare_graph(parameters_to_compare=['training_method'], result_to_compare=['val_acc1'])
# Out:
# (<Figure size 936x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f739ddf23c8>)

# %%
experiment_list = [full_experiment]
names_list = ['TAS']


for name,experiment in zip(names_list, experiment_list):
    

    print(experiment.make_latex_table(parameter_list=['training_method'], 
                                      result_list=['val_acc1', 'val_loss'],
                                      result_type_list=['max_mean', 'min_mean'],
                                      name=name,
                                      precision=3))
# Out:
# \multirow{3}{*}{TAS}
#  & adam & 90.605 ($\pm$ 0.405) & 0.473 ($\pm$ 0.032) \\
#  & sgd & 90.305 ($\pm$ 0.045) & 0.477 ($\pm$ 0.003) \\
#  & sgd & 92.40 ($\pm$ 0.070) & 0.420 ($\pm$ 0.001) \\
# \midrule
