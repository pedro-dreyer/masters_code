# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append('..')
from misc.experiment_loader import *
# import matplotlib.pyplot as plt


folder_path = '../results/mnist/lenet5/best_results_vgg19/'
full_experiment = FullExperiment(folder_path=folder_path)

# %%
full_experiment.plot_compare_graph(parameters_to_compare=['training_method'], result_to_compare=['val_acc1'])
# Out:
# (<Figure size 936x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa63b3bcf60>)

# %%
experiment_list = [full_experiment]
names_list = ['TAS']


for name,experiment in zip(names_list, experiment_list):
    

    print(experiment.make_latex_table(parameter_list=['training_method'], 
                                      result_list=['val_acc1', 'val_loss'],
                                      result_type_list=['max_mean', 'min_mean'],
                                      name=name,
                                      precision=3))
# Out:
# \multirow{5}{*}{TAS}
#  & adagrad & 77.715 ($\pm$ 4.295) & 1.160 ($\pm$ 0.198) \\
#  & adam & 99.145 ($\pm$ 0.035) & 0.028 ($\pm$ 0.002) \\
#  & rmsprop & 99.110 ($\pm$ 0.010) & 0.029 ($\pm$ 0.001) \\
#  & sgd & 99.125 ($\pm$ 0.065) & 0.030 ($\pm$ 0.003) \\
#  & sgd & 99.110 ($\pm$ 0.050) & 0.029 ($\pm$ 0.002) \\
# \midrule
