# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append('..')
from misc.experiment_loader import *
# import matplotlib.pyplot as plt


folder_path = '../results/cifar100/vgg19bn_/best_results_cifar_10/'
full_experiment = FullExperiment(folder_path=folder_path)
test_experiment = full_experiment.filter_parameters({'training_method':'sgd'})

# %%
test_experiment.plot_compare_graph(parameters_to_compare=['training_method'], result_to_compare=['val_acc1'])
# Out:
# (<Figure size 936x360 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f18adba86a0>)

# %%
for experiment in test_experiment.list:
    print(experiment.parameters_dict)
    print('-----------')
# Out:
# {'sgd_lr': 0.05, 'sgd_momentum': 0.9, 'sgd_weight_decay': 0, 'sgd_dampening': 0, 'sgd_nesterov': False, 'architecture': 'vgg19bn_', 'dataset': 'cifar100', 'combine_datasets': False, 'do_validation_set': False, 'epochs': 100, 'batch_size': 1024, 'test_set_split': 0.1666667, 'validation_set_split': 0.0, 'reduce_train_set': 1.0, 'executions': 2, 'base_seed': 1230, 'training_method': 'sgd', 'learning_method': 'constant', 'bach_size': 1024}
# -----------
# {'tas_alpha': 25, 'tas_beta': 0.7, 'tas_gamma': 0.02, 'sgd_lr': 0.05, 'sgd_momentum': 0, 'sgd_weight_decay': 0, 'sgd_dampening': 0, 'sgd_nesterov': False, 'architecture': 'vgg19bn_', 'dataset': 'cifar100', 'combine_datasets': False, 'do_validation_set': False, 'epochs': 100, 'batch_size': 1024, 'test_set_split': 0.1666667, 'validation_set_split': 0.0, 'reduce_train_set': 1.0, 'executions': 2, 'base_seed': 1230, 'training_method': 'sgd', 'learning_method': 'tas', 'bach_size': 1024}
# -----------
