# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append('..')
from misc.experiment_loader import *
# import matplotlib.pyplot as plt


folder_path = '../results/cifar100/vgg19bn_/best_results_cifar_10/'
full_experiment = FullExperiment(folder_path=folder_path)
# Out:
# /home/pedro/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/pedro/anaconda3/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
fig1, ax1 = full_experiment.plot_compare_graph(parameters_to_compare=['training_method'], result_to_compare=['val_acc1'])
fig2, ax2 = full_experiment.plot_compare_graph(parameters_to_compare=['training_method'], result_to_compare='train_acc1')

# %%
lines = ax1.lines
for line in lines:
    ax2.plot(line.get_xdata(), line.get_ydata(), color=line.get_color(), linestyle='--')

# %%
ax2.legend(['Adagrad','Adam', 'Rmsprop', 'SGD', 'TASO'])
fig2.set_size_inches(7,5)
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.set_ylim(0,105)
ax2.set_xlim(0,100)
fig2.suptitle('')
plt.setp(ax2.spines.values(), linewidth=1.5)
fig2

# %%
fig2.savefig('test.pdf', format='pdf', bbox_inches='tight')

# %%
experiment_list = [full_experiment]
names_list = ['TAS']


for name,experiment in zip(names_list, experiment_list):
    

    print(experiment.make_latex_table(parameter_list=['training_method'], 
                                      result_list=['val_acc1', 'val_loss'],
                                      result_type_list=['max_mean', 'min_mean'],
                                      name=name,
                                      precision=3))
# Out:
# \multirow{5}{*}{TAS}
#  & adagrad & 1.185 ($\pm$ 0.015) & 4.664 ($\pm$ 0.017) \\
#  & adam & 61.465 ($\pm$ 0.165) & 1.874 ($\pm$ 0.043) \\
#  & rmsprop & 55.330 ($\pm$ 1.430) & 1.974 ($\pm$ 0.011) \\
#  & sgd & 64.695 ($\pm$ 0.185) & 1.739 ($\pm$ 0.013) \\
#  & sgd & 65.020 ($\pm$ 0.240) & 1.748 ($\pm$ 0.007) \\
# \midrule
