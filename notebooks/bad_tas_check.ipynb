# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
sys.path.append('..')
from misc.experiment_loader import *
# import matplotlib.pyplot as plt


folder_path = '../results/cifar10/vgg19bn_/tas_bad_parameters/'
full_experiment = FullExperiment(folder_path=folder_path)

# %%
full_experiment.list[0].results_ds
# Out:
# <xarray.Dataset>
# Dimensions:        (epoch: 30, execution: 2)
# Coordinates:
#   * epoch          (epoch) int64 1 2 3 4 5 6 7 8 9 ... 23 24 25 26 27 28 29 30
#   * execution      (execution) int64 1 2
# Data variables:
#     train_acc1     (execution, epoch) float64 21.38 36.06 37.65 ... 80.67 80.9
#     val_acc1       (execution, epoch) float64 33.1 38.04 39.07 ... 76.83 78.26
#     train_loss     (execution, epoch) float64 2.174 1.685 1.631 ... 0.552 0.543
#     val_loss       (execution, epoch) float64 1.821 1.623 1.603 ... 0.688 0.631
#     learning_rate  (execution, epoch) float64 0.04967 0.001328 ... 0.001 0.001

# %%
full_experiment.plot_compare_graph(parameters_to_compare=['sgd_lr'], result_to_compare=['learning_rate'])

# %%
full_experiment.plot_compare_graph(parameters_to_compare=['sgd_lr'], result_to_compare=['val_acc1'])
